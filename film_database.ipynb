# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('tmdb_movies.csv')
df.head()
# Out:
#    Unnamed: 0     budget                                      homepage  \
# 0           0  237000000                   http://www.avatarmovie.com/
# 1           1  300000000  http://disney.go.com/disneypictures/pirates/
# 2           2  245000000   http://www.sonypictures.com/movies/spectre/
# 3           3  250000000            http://www.thedarkknightrises.com/
# 4           4  260000000          http://movies.disney.com/john-carter
#
#        id original_language                            original_title  \
# 0   19995                en                                    Avatar
# 1     285                en  Pirates of the Caribbean: At World's End
# 2  206647                en                                   Spectre
# 3   49026                en                     The Dark Knight Rises
# 4   49529                en                               John Carter
#
#                                             overview  popularity release_date  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count      genre_id
# count  4801.000000   4803.000000   4803.000000   4775.000000
# mean    106.875859      6.092172    690.217989    634.411309
# std      22.611935      1.194612   1234.585891   2415.010323
# ...

# %% [markdown]
# Zwróć listę 10 najwyżej ocenianych filmów (vote_average), których liczba głosów (vote_count) jest większa od 3. kwartyla rozkładu liczby głosów.

# %%
df[df['vote_count']>df.vote_count.quantile(0.75)].sort_values(by='vote_average',ascending=False).head(10)
# Out:
#       Unnamed: 0    budget                                    homepage  \
# 1881        1881  25000000                                         NaN
# 3337        3337   6000000                http://www.thegodfather.com/
# 2294        2294  15000000      http://movies.disney.com/spirited-away
# 3865        3865   3300000           http://sonyclassics.com/whiplash/
# 2731        2731  13000000                                         NaN
# 3232        3232   8000000                                         NaN
# 1818        1818  22000000              http://www.schindlerslist.com/
# 662          662  63000000  http://www.foxmovies.com/movies/fight-club
# 2170        2170    806948                                         NaN
# 1847        1847  25000000        http://www.warnerbros.com/goodfellas
#
#           id original_language            original_title  \
# 1881     278                en  The Shawshank Redemption
# 3337     238                en             The Godfather
# ...

# %% [markdown]
# Pogrupuj tabelę w taki sposób, aby otrzymać średni przychód (revenue) oraz średni budżet (budget) w danym roku dla filmów opublikowanych od 2010 (włącznie) do 2016 roku (włącznie). Następnie na tej podstawie stwórz wykres, w którym średnie przychody są wykresem kolumnowym, a średni budżet wykresem liniowym na tych samych osiach. Sformatuj odpowiednio oś X oraz oś Y. Dodaj tytuł wykresu, oraz legendę, która znajduje się w prawym górnym rogu płótna, lecz poza obszarem osi. Przykład wykresu widoczny poniżej:

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year
df2 = df[(df['year'] >= 2010) & (df['year'] <= 2016)].sort_values(by='year')

# %%
df3 = df2.pivot_table(values=['budget','revenue'],index='year',aggfunc=np.mean)
df3
# Out:
# C:\Users\Sławek\AppData\Local\Temp\ipykernel_23848\3820839251.py:1: FutureWarning: The provided callable <function mean at 0x0000019EDF034220> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df3=df2.pivot_table(values=['budget','revenue'],index='year',aggfunc=np.mean)
#               budget       revenue
# year
# 2010.0  3.449541e+07  9.043811e+07
# 2011.0  3.477232e+07  9.200413e+07
# 2012.0  3.492203e+07  1.160659e+08
# 2013.0  3.552329e+07  1.013485e+08
# 2014.0  3.095989e+07  1.013466e+08
# 2015.0  3.113216e+07  1.054399e+08
# 2016.0  4.570327e+07  1.390496e+08

# %%
def million(x, pos):
        return '{:2.1f}M'.format(x*1e-6)

import matplotlib.pyplot as plt
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.bar(df3.index,df3['revenue'], label = 'revenue')
axes.plot(df3.index,df3['budget'], color='red', label = 'budget')
formatter = plt.FuncFormatter(million)
axes.yaxis.set_major_formatter(formatter)
axes.set_title('Średni przychód i budżet filmu w latach 2018 - 2016')
axes.legend(loc=(1.05,0.9))

# %% [markdown]
# Baza filmów zawiera kolumnę z id gatunku (genre_id). Na tej podstawie połącz ze sobą bazę filmów z bazą gatunków, tak aby w bazie filmów można było odczytać nazwę gatunku filmu.

# %%
genre = pd.read_csv('tmdb_genres.csv')
genre_dict = dict(zip(genre['Unnamed: 0'],genre['genres']))
df['genre_name'] = df['genre_id'].map(genre_dict)
df.drop('Unnamed: 0',axis=1)
# Out:
#          budget                                           homepage      id  \
# 0     237000000                        http://www.avatarmovie.com/   19995
# 1     300000000       http://disney.go.com/disneypictures/pirates/     285
# 2     245000000        http://www.sonypictures.com/movies/spectre/  206647
# 3     250000000                 http://www.thedarkknightrises.com/   49026
# 4     260000000               http://movies.disney.com/john-carter   49529
# ...         ...                                                ...     ...
# 4798     220000                                                NaN    9367
# 4799       9000                                                NaN   72766
# 4800          0  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801          0                        http://shanghaicalling.com/  126186
# 4802          0                                                NaN   25975
#
#      original_language                            original_title  \
# ...

# %% [markdown]
# Jaki gatunek filmu z bazy pojawia się w niej najczęściej? Ile filmów tego gatunku znajduje się w bazie?

# %%
df['genre_name'].value_counts()
# Out:
# genre_name
# Drama              1207
# Comedy             1042
# Action              754
# Adventure           339
# Horror              300
# Crime               195
# Thriller            194
# Animation           123
# Fantasy             117
# Romance             106
# Science Fiction      96
# Documentary          89
# Family               56
# Mystery              41
# Music                34
# Western              27
# History              25
# War                  24
# TV Movie              4
# Foreign               2
# Name: count, dtype: int64

# %% [raw]
# Najczęściej pojawia się dramat, liczba filmów to 1207.

# %% [markdown]
# Filmy, którego gatunku trwają średnio najdłużej (runtime)?

# %%
df4 = df.pivot_table(values=['runtime'],index='genre_name',aggfunc=np.mean).sort_values(by='runtime',ascending=False)
df4
# Out:
# C:\Users\Sławek\AppData\Local\Temp\ipykernel_25624\3492982954.py:1: FutureWarning: The provided callable <function mean at 0x000002A658A38720> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df4 = df.pivot_table(values=['runtime'],index='genre_name',aggfunc=np.mean).sort_values(by='runtime',ascending=False)
#                     runtime
# genre_name
# History          133.960000
# War              126.125000
# Western          117.925926
# Drama            115.521559
# Adventure        113.061947
# Crime            112.143590
# TV Movie         110.500000
# Action           109.058355
# Science Fiction  109.031250
# Romance          107.094340
# Fantasy          106.487179
# Thriller         105.690722
# Music            102.852941
# Mystery          100.609756
# Comedy           100.464491
# Horror            94.753333
# Documentary       93.511364
# ...

# %% [raw]
# Najdłużej trwają filmy historyczne

# %% [markdown]
# Stwórz histogram czasu trwania filmów z gatunku, który cechuje się największym średnim czasem trwania.

# %%
df5 = df[df['genre_name'] == 'History']
df5['genre_name'].value_counts()
# Out:
# genre_name
# History    25
# Name: count, dtype: int64

# %%
df5['runtime'].hist()
# Out:
# <Axes: >
